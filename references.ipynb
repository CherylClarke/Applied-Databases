# %% [markdown]
# References:
#
# Lectures and demos by Gerard Harrison in Applied Databases 2026.
#
# W3schools (2026) SQL Tutorials (online) available from : https://www.w3schools.com/sql/default.asp [accessed 28 April].
#
# neo4j docs (2026) what is a graph database (online) available from: https://neo4j.com/docs/getting-started/graph-database/ [accessed 28 April 2026].
#
# geeksforgeeks (2026) Neo4j : The Graph Database (online) available from: https://www.geeksforgeeks.org/dbms/neo4j-introduction/ [accessed 1 may 2026].
#
# neo4j docs (2026) Comparing Cypher with SQL (online) available from: https://neo4j.com/docs/getting-started/cypher/cypher-sql/ [accessed 1 may 2026].
#
# Stack Overflow (2026) how can i import mysql in neo4j windows? (online) available from: https://stackoverflow.com/questions/38458240/how-can-i-import-mysql-database-in-neo4j-on-windows [accessed 2 may 2026].
#
# Chatgpt (2026) prompt: "step by step of building order"https://chatgpt.com/c/69fa60fa-29f4-8390-998c-0cba7b12a1ad [accessed 9 May 2026].
#
# Chatgpt (2026) prompt: "Write a python application that displays a main menu as follows" available from : https://chatgpt.com/c/69ff6126-da5c-83eb-b21f-0fd3beded0c8 [accessed 5 may 2026].
